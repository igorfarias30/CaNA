# %%
import matplotlib.pyplot as plt
from asterisco import asterisco
import numpy as np
import time

# %%
constants = np.arange(1, 3000, 5)

# %%
y = [7 * constant * np.log(constant) for constant in constants]

# %%
times = []
executions = []

for constant in constants:
    start = time.time()
    executions.append(asterisco(constant, a=2, b=3, c=1, d=7))
    times.append(time.time() - start)

# %%
fig, ax1 = plt.subplots(figsize=(16, 8))

color = 'tab:red'
ax1.set_xlabel('N - size')
ax1.set_ylabel('time (s)', color=color)
ax1.plot(constants, times, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('executions', color=color)  # we already handled the x-label with ax1
ax2.plot(constants, executions, color=color)
ax2.plot(constants, y, color='g')
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.grid()
plt.show()
